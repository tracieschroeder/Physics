# %% [markdown]
# <a href="https://colab.research.google.com/github/tracieschroeder/Physics/blob/main/3_The_Incline_Lab_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**The Incline Lab**
# Objective:  To determine how the position and velocity of car moving up and down an incline.

# %% [markdown]
# ##**The Experimental Setup:**
# 1.	Use 3-4 textbooks to set up an incline ramp on the floor. Place the motion sensor at the top, pointing straight down the ramp.
#
# 2. Open the Graphical Analysis app and plug the motion sensor into a USB port of your Chromebook. Set the reference point by holding your hand next to the sensor and click on the button at the bottom right hand corner of the app. Choose to view 1 Graph from the top right corner menu.
#
# 3. Hold the car at the top of the ramp. To start collecting data, click on the Collect button. We tend to get better results if we click on it and then release the car rather than trying to do both at the same time.
#
# 4. Highlight the part of the graph that represents the motion of the car moving on the ramp.
#
#
# You will need four sets of data:
# - Car rolling down the ramp away from the sensor
# - Car rolling down the ramp towards the sensor
# - Car rolling up the ramp away from the sensor (give it a LIGHT push)
# - Car rolling up the ramp towards the sensor

# %% [markdown]
# ##Saving the Data
#
# Choose Export from the File menu (the page icon).
#
# Choose .CSV and name the file
#
# Copy this data into an excel file and upload into Google Drive. Change the permissions so that anyone with the link has access. Copy the share link.
#
# Change the column headings to something more manageable if you want to.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# After completing your data table, make your file shareable and edit the link by deleting out the "edit?usp=sharing" part of the address and add /export at the end.
# Use the following format
#
# ('https://docs.google.com/spreadsheets/d/1ffmFTOJai6IPpGrY9VEH7reU1VdsHjSXWJKjyNJM-F4/export'

# %%
data = pd.read_excel('https://docs.google.com/spreadsheets/d/16ObGPq8slGEzLTKEFBOJ8egZuXCWhGIb/export')
data.head(5)
# Out:
#    1Time  1Position  1Velocity  1Acceleration  2Time  2Position  2Velocity  \
# 0   0.00   0.135155   0.035263      -0.480108   0.00   1.948625  -0.894912
# 1   0.05   0.138566   0.002133      -0.327442   0.05   1.908734  -1.018579
# 2   0.10   0.133146   0.009749      -0.297102   0.10   1.853012  -1.160602
# 3   0.15   0.142220  -0.022120      -0.353815   0.15   1.789062  -1.239559
# 4   0.20   0.130929  -0.051557       0.081213   0.20   1.725510  -1.252043
#
#    2Acceleration  3Time  3Position  ...  8Velocity  8Acceleration  9Time  \
# 0      -2.505238   0.00   1.967748  ...  -0.845492      -2.882269   0.00
# 1      -2.391941   0.05   1.967783  ...  -0.895825      -3.398202   0.02
# 2      -1.926194   0.10   1.967834  ...  -0.968483      -4.065626   0.04
# 3      -0.990207   0.15   1.967627  ...  -1.061136      -4.555585   0.06
# 4       0.079454   0.20   1.967644  ...  -1.163632      -4.385472   0.08
#
#    9Position  9Velocity  9Acceleration  10Time  10Position  10Velocity  \
# ...

# %% [markdown]
# #**Learning Check!**
# What kind of document is the program reading the data from?
# Change the '5' in the data.head command to '10'. What does this line of code do?

# %% [markdown]
# #Dealing with the Data
#
# That is a lot of data...

# %% [markdown]
# Let's start with the first set of data.

# %%
x = data['1Time']  #Which column do we want to graph?
y = data['How can we put the position data for Trial 1 here?'] #Which column do we want to graph?

plt.scatter(x, y, marker='o', color='r')  #add points to the graph using the v marker and red color
#plt.xlim(0,1)
plt.title('Scatter Plot Example')
plt.xlabel("Fix Me")
plt.ylabel("Me To!")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'How can we put the position data for Trial 1 here?'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Looking at this plot, we some points that are from before and after the car was moving. Look at Line 5 in the code box above. Uncomment that line. Adjust the code so that the graph only shows the data points that we want.

# %% [markdown]
# ##Learning Check

# %% [markdown]
# #Position Time Graphs
# We took data for four different scenarios of the car moving up and down the ramp. It would be super helpful to be able to see all of the graphs in one place.

# %%
#Create a separate data set for each trial

#Down the ramp away from the sensor
x1 = #HINT: What did we use to graph the first set of data?
y1 =

#Down the ramp towards the sensor
x2 =
y2 =

#Up the ramp away from the sensor
x3 =
y3 =

#Up the ramp towards the sensor
x4 =
y4 =

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,5))
fig.subplots_adjust(hspace=0.5)

ax[0,0].plot(x1, y1, color= 'chartreuse', label='one', linestyle="--")
ax[0,0].set_xlim(0,2.3)
ax[0,0].legend()

ax[1,0].plot('Plot the data for the car moving down and towards the sensor')
ax[1,0].set_title("this is a title")
ax[1,0].annotate('there is nothing here',xy=(.5, .5), xytext=(.2, .7), arrowprops=dict(facecolor='black', arrowstyle="->"))
ax[1,0].spines['top'].set_visible(False)
ax[1,0].spines['right'].set_visible(False)
ax[1,0].spines['bottom'].set_color('#565656')

ax[0,1].plot('What data should be plotted here')
ax[0,1].set(xlabel="some label", ylabel="other label", title="a title?")
ax[0,1].xaxis.set_ticks_position('none')
ax[0,1].tick_params(labelcolor='grey')
ax[0,1].grid(color='#565656', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

ax[1,1].plot('Last data set goes here')
ax[1,1].axhline(.5, color='purple')
ax[1,1].text(.5, .2, "text!")

plt.show()

# %% [markdown]
# #Velocity Time Graphs
# Now create a Velocity Time Graph for each example.

# %%
#What data do we need to pull in to create a velocity time graph for each trial?
#Create a separate data set for each trial

#Down the ramp away from the sensor


#Down the ramp towards the sensor


#Up the ramp away from the sensor


#Up the ramp towards the sensor

# %%
#Let's put all four of them in one space, just like we did with the position time graphs
